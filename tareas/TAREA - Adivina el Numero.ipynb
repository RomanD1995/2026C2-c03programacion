# %% [markdown]
# # TAREA - Adivina el número
# ## Semana 05 | Fundamentos de Python
# ### Profesor: Ing. Andrés Mena Abarca
#
# **Nombre del estudiante:** _Adonis_Roman_Dinarte
#
# ---
#
# ## Propósito
#
# Crear un juego corto que use variables, entrada de datos, conversión con
# `int()`, comparaciones, decisiones, la librería `random` y una primera
# introducción a `while True` y `break`.
#
# Esta tarea es un adelanto controlado hacia Semana 06. Los ciclos se estudiarán
# con más detalle después; aquí interesa entender por qué un programa puede
# necesitar repetir instrucciones hasta que ocurra una condición de salida.

# %% [markdown]
# ## 1. ¿Qué hacen `while True` y `break`?
#
# Un ciclo `while` repite instrucciones mientras una condición sea verdadera.
# Cuando escribimos `while True`, la condición siempre es verdadera, así que el
# ciclo necesita una salida explícita. Esa salida se logra con `break`.
#
# Use este patrón cuando no sabe de antemano cuántas veces se repetirá una
# acción. Por ejemplo: pedir una opción válida, esperar una palabra correcta o
# continuar un juego hasta que el usuario acierte.

# %% [markdown]
# ## 2. Ejemplo corto: repetir hasta escribir una palabra
#
# Ejecute el ejemplo y observe dónde aparece la salida del ciclo.

# %%
while True:
    palabra = input("numero 10").strip().lower()

    if palabra == "10":
        print("Programa finalizado.")
        break

    print("Todavía no termina.")
# Out:
# Todavía no termina.
# Todavía no termina.
# Todavía no termina.
# Todavía no termina.
# Todavía no termina.
# Todavía no termina.
# Todavía no termina.
# Programa finalizado.

# %% [markdown]
# ## 3. Ejemplo corto: repetir hasta cumplir una condición numérica
#
# Este ejemplo usa `int()` porque `input()` siempre recibe texto.

# %%
while True:
    numero = int(input("Escriba un número mayor que 10: "))

    if numero > 10:
        print("Número aceptado.")
        break

    print("Debe intentar otra vez.")
# Out:
# Debe intentar otra vez.
# Debe intentar otra vez.
# Debe intentar otra vez.
# Debe intentar otra vez.
# Debe intentar otra vez.
# Debe intentar otra vez.
# Número aceptado.

# %% [markdown]
# ## 4. Mini introducción a la librería `random`
#
# Python trae librerías listas para resolver tareas comunes. La librería
# `random` permite generar valores al azar. Para usarla, primero se importa y
# luego se llama una de sus funciones.
#
# En este juego puede usar `random.randint(inicio, fin)` para crear un número
# secreto entero dentro de un rango.

# %%
import random

numero_ejemplo = random.randint(1, 100)
print(f"Número generado: {numero_ejemplo}")
# Out:
# Número generado: 20

# %% [markdown]
# ## 5. Análisis antes de crear el juego
#
# Responda antes de programar:
#
# 1. ¿Qué dato se genera una sola vez al inicio del juego? el numero a adivinar genetardo por la libreria ramdom
# 2. ¿Qué dato cambia en cada intento? el numero en el contador en la variable intentos
# 3. ¿Qué condición permite terminar el ciclo? acertar el numero secreto o una salida tracera que agrege al detalle del juego
# 4. ¿Cómo calculará qué tan cerca está el intento del número secreto? usando la funcion abs() para calcular la diferencia
# 5. ¿Qué mensajes de temperatura recibirá el usuario para acercarse a la respuesta? frio ,tivio y calente ademas irviendo si la distancia es muy pequeña.
# 6. ¿Qué variable podría contar cuántos intentos realizó el usuario?
# intentos= 0 fuera del bucle
# y dentro del bucle
# intentos += 1
# asi suma 1 cada ves que el codigo pasa por ahi

# %% [markdown]
# ## 6. Consigna: Adivina el número
#
# Cree un juego llamado **Adivina el número: frío o caliente**.
#
# El programa debe:
#
# 1. Generar un número secreto al azar entre 1 y 20 usando `random.randint()`.
# 2. Pedir intentos al usuario hasta que acierte.
# 3. Convertir cada intento a número entero.
# 4. Comparar el intento con el número secreto.
# 5. Dar pistas de dirección: si el número secreto es mayor o menor que el intento.
# 6. Dar pistas de temperatura según la distancia al número secreto.
# 7. Felicitar al usuario cuando acierte.
# 8. Mostrar cuántos intentos realizó el usuario.
# 9. Terminar el ciclo con `break` cuando el usuario acierte.
#
# ### Reglas de temperatura
#
# Use la distancia entre el intento y el número secreto para crear pistas más
# creativas. La distancia debe ser siempre positiva.
#
# Para calcular una distancia positiva puede usar `abs()`. Por ejemplo,
# `abs(3 - 8)` produce `5`, no `-5`.
#
# Puede usar esta escala o proponer una equivalente:
#
# | Distancia al número secreto | Pista sugerida |
# |---:|---|
# | `0` | Acertó. Termina el juego. |
# | `1` o `2` | Hirviendo: está casi encima del número. |
# | `3` a `5` | Caliente: está cerca. |
# | `6` a `10` | Tibio: va por buen camino, pero falta. |
# | Más de `10` | Frío: está lejos. |
#
# Ejemplo de experiencia esperada:
#
# ```text
# Intento: 4
# El número secreto es mayor. Pista: frío.
#
# Intento: 13
# El número secreto es menor. Pista: caliente.
#
# Intento: 11
# Correcto. Adivinó en 3 intentos.
# ```
#
# ### Restricciones
#
# - No utilice listas.
# - No utilice funciones propias.
# - No agregue validación de errores todavía.
# - No copie una plantilla: use los ejemplos como referencia, pero diseñe su
#   propia solución.

# %% [markdown]
# ## 7. Plan de variables
#
# Complete esta tabla antes de escribir el código.
#
# | Variable que usará | Tipo esperado | ¿Qué representa? | ¿Cuándo cambia? |
# |---|---|---|---|
# |intento|  int  |  el numero de veces que nesecito el usuario para acertar|con cada intento nuevo  |
# | direccion |  str| hacia donde deve dirigir el siguiente numero para estar mas cerca |si superamos ya cea hacia arriba o hacia abajo del numero secreto  |
# |numero_secreto  |int  | el numero a adivinar | cada ves que se inicie el programa pero durante el mismo no cambia |
# |numero_usuario  |  int  | el numero que ingresa el usuario |con cada numero que ingrese el usuario|
# |  distancia|int  | la distancia que hace falta para llegar al numero secreto | en cusanto mas nos acerquemos |
# |temp|str   |que tan cerca estamos del numero en terminos de temperatura  |en cuanto mas nos acerquemos

# %% [markdown]
# ## 8. Código del estudiante
#
# Escriba aquí su solución completa.

# %%
#juego de frio o caliente generando un numero aleatorio




import random


numero_secreto = random.randint(1, 20)

# contador
intentos = 0#  +1 cada ves que se repite el bucle

print("¡Bienvenido al juego: Adivina el número: frío o caliente! masomenos ")
print("He pensado un número secreto entre 1 y 20.")


while True:
     
    numero_usuario = int(input("Introduce su numero para adivinar o 0 para salir: "))
    intentos += 1 #como el bucle se repite cada ves que pasa por aqui suma 1 intento a la variable fuera del bucle
    distancia = abs(numero_usuario - numero_secreto) # use abs paravcalcular la distancia entre los nuemros
    
   
    if numero_usuario == numero_secreto or numero_usuario == (0) :# si el numero es correcto aqui se cierra el bucle o el usuari decide sali del juego 
        
         if numero_usuario == numero_secreto:
             print("felicidades acertaste ...")
         else:print("decidiste salir del juego")
         break
    
    #lo dividi en dos bloques el de la direcion y el de la temperatura
        
        
    if numero_secreto > numero_usuario:  #aqui le digo que si el numeros cecreto es mayor que el del usuario la variable direcion es meyor
        direccion = "El número secreto es mayor."
    else:
        direccion = "El número secreto es menor." # de lo contrario es menor
      

    #las temperatura con los casos especificados y en ultimo caso la pista frio
    if distancia == 1 or distancia == 2:
        temp = "aaaaay estamos hirbiendo estás casi encima del número."
    elif 3 <= distancia <= 5:
        temp = "casi nos quemanos caliente: está cerca."
    elif 6 <= distancia <= 10:
        temp = "tibio va por buen camino, pero falta."
    else:
        temp = "que frío: está lejos."
     
     
      # ahora imprimo la direcion y la temp0eratura que cumpla las condiciones  
    print ("\n")
    print (f"tu nomero es ---  {numero_usuario}  --- {direccion} {temp}")
    print (f"este es su {intentos}° intento ")
    

# solo imprimo la variable intentos que se sumo mas arriba
print(f"usaste : {intentos} intentos.")



print(type(intentos))
print(type(direccion))
print(type(numero_secreto))
print(type(numero_usuario))
print(type(distancia))
print(type(temp))
# Out:
# ¡Bienvenido al juego: Adivina el número: frío o caliente! masomenos
# He pensado un número secreto entre 1 y 20.
#
#
# tu nomero es ---  5  --- El número secreto es mayor. casi nos quemanos caliente: está cerca.
# este es su 1° intento
#
#
# tu nomero es ---  10  --- El número secreto es menor. aaaaay estamos hirbiendo estás casi encima del número.
# este es su 2° intento
#
#
# tu nomero es ---  8  --- El número secreto es mayor. aaaaay estamos hirbiendo estás casi encima del número.
# este es su 3° intento
# felicidades acertaste ...
# usaste : 4 intentos.
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ## 9. Evidencia de pruebas
#
# Registre tres ejecuciones manuales. Puede copiar la salida de la consola o
# describir exactamente qué escribió y qué respondió el programa.
#
# | Prueba | Intentos realizados | Pistas de dirección y temperatura | Resultado observado |
# |---|---|---|---|
# | Intento frío | este es su 1° intento  |El número secreto es mayor. que frío:|  tu nomero es ---  1  --- El número secreto es mayor. que frío: está lejos.
# | Intento caliente o hirviendo | este es su 4° intento  |  El número secreto es mayor. casi nos quemanos caliente|  tu nomero es ---  12  --- El número secreto es mayor. casi nos quemanos caliente: está cerca.
# | Intento correcto | usaste : 9 intentos. | -------- | felicidades acertaste ...

# %% [markdown]
# ## 10. Reflexión
#
# Responda con dos o tres oraciones:
#
# 1. ¿Por qué este programa necesita repetir instrucciones?
#  1 por la funcionalidad del juego par que el ususario tenga la oportunidad de acertar y no se congele o se tenenga el programa
#
# 2. ¿Dónde termina el ciclo y por qué?
#  cuendo adivina el numero secreto , por la funcion while _break qu eestablecimos<>
#
# 3. ¿Cómo usó la distancia para decidir si el intento estaba frío, tibio, caliente o hirviendo?
#  imponiendo una variable pista_temp que cambia dependiado de las distancia data por el calculo de abs() entre el numero_usuario y el numero_secreto y abs() simpre entrega un numero positivo
